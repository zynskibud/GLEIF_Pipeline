# %%
import os
import logging
import json
import json
import psycopg2
import sys
import io
current_directory = os.getcwd()
target_directory = os.path.abspath(os.path.join(current_directory, "..", ".."))
sys.path.append(target_directory)

from Production.Update import GLEIF_Update_Helpers
from Production.Backfill import GLEIF_Backfill_Helpers

# %%
class GLEIFUpdateExceptions:
    def __init__(self , bool_log = True , str_db_name = "GLEIF_test_db" , bool_downloaded = True):
        self.obj_update_helpers = GLEIF_Update_Helpers.GLEIF_Update_Helpers(bool_Level_2_Reporting_Exceptions = True)
        self.obj_backfill_helpers = GLEIF_Backfill_Helpers.GLEIF_Backill_Helpers(bool_Level_2_Reporting_Exceptions = True)
        if bool_log:
            logging_folder = "../logging"  # Adjust the folder path as necessary
    
            if os.path.exists(logging_folder):
                if not os.path.isdir(logging_folder):
                    raise FileExistsError(f"'{logging_folder}' exists but is not a directory. Please remove or rename the file.")
            else:
                os.makedirs(logging_folder)
    
            logging.basicConfig(filename=f"{logging_folder}/GLEIF_Update_level_2.log", level=logging.DEBUG, format='%(levelname)s: %(message)s', filemode="w")

        if not bool_downloaded:
            if not os.path.exists("../file_lib"):
                os.makedirs("../file_lib")
                
            self.obj_update_helpers.download_on_machine()
            self.str_json_file_path = self.obj_update_helpers.unpacking_GLEIF_zip_files()
    
        self.str_json_file_path = '../file_lib/Exceptions_update_unpacked\\20241130-0000-gleif-goldencopy-repex-intra-day.json'
        self.conn = psycopg2.connect(dbname = str_db_name, user="Matthew_Pisinski", password="matt1", host="localhost", port="5432")    
        self.conn.autocommit = True
        self.cursor = self.conn.cursor()
        
    def bulk_insert_using_copy(self , table_name , columns, data):
        """Perform a bulk insert using PostgreSQL COPY with an in-memory buffer

        Args:
            table_name (_type_): Name of the table to insert into
            columns (_type_): List of column names for the table
            data (_type_): List of tuples with the data to be inserted
        """
        
        buffer = io.StringIO()
        
        #write data to the buffer
        
        for row in data:
            buffer.write('\t'.join(map(str , row)) + "\n")
        buffer.seek(0) #reset buffer position to the beginning
        
        #Construct the copy query
        copy_query = f"COPY {table_name} ({', '.join(columns)}) FROM STDIN WITH DELIMITER '\t'"
        self.cursor.copy_expert(copy_query , buffer)
        self.conn.commit
        
    def process_data(self , dict_leis):
        list_tuples_exceptions = []
    
        for dict in dict_leis:
            dict_flat = self.obj_backfill_helpers.flatten_dict(dict_input = dict)
            tuple_values = self.obj_backfill_helpers.get_target_values(dict_data = dict_flat , subset_string = True , target_keys = ["LEI" , "ExceptionCategory" , "ExceptionReason"])
            list_tuples_exceptions.append(tuple(tuple_values))
            
        self.bulk_insert_using_copy(data = list_tuples_exceptions , table_name = "GLEIF_exception_data" , columns = ['lei' , 'ExceptionCategory' , 'ExceptionReason'])
        
    def storing_GLEIF_data_in_database(self):
        
        with open(self.str_json_file_path, 'r', encoding='utf-8') as file:
            dict_leis = json.load(file)
            
        display(dict_leis)
        self.process_data(dict_leis = dict_leis["exceptions"])
        
        
        self.conn.close()

# %%
obj_gleif_reporting_exceptions = GLEIFUpdateExceptions()
obj_gleif_reporting_exceptions.storing_GLEIF_data_in_database()
# Out:
# {'exceptions': [{'LEI': {'$': '0KH67AG8S2C0UUDZ7J79'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '0VNOQKIRP7AG4HT7MV54'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_LEI'}]},
#   {'LEI': {'$': '1595864AH8IQOAO8MN68'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '21380015NAOGHT7Y8K56'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '2138001HU2ZPUUJDLF56'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '2138001PVGZQBUUNZU94'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '2138001SMTNGYZWN8L24'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '2138002MCSEY4B2DYF93'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '2138002YECP3YD2CWG54'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '21380037F9CCOOPWRW72'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '2138003KTI9VVKORR132'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '213800532NG6A52F4U27'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_KNOWN_PERSON'}]},
#   {'LEI': {'$': '2138005F1TH9E4QXON92'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '2138006LE8XTCB8FB938'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '2138006PBZSUSLTKXQ75'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '2138006S46J9FER7S592'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '21380073HIMQ67B14423'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_PUBLIC'}]},
#   {'LEI': {'$': '2138007SPLB85W931B76'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '2138008DIRJP5LQAOM27'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_KNOWN_PERSON'}]},
#   {'LEI': {'$': '2138008PUI2C2NMMA489'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '2138009GKB2C82B4E532'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '2138009RV9X2KM5S8844'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_KNOWN_PERSON'}]},
#   {'LEI': {'$': '213800A3BA8XON1FLM32'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_LEI'}]},
#   {'LEI': {'$': '213800A84QVGXT7C2Z72'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '213800ALOH88A2VLJP44'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '213800AVAMERVU64JV75'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '213800BHPAP6T84Y4L83'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '213800BXTH1XYWD26K16'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_LEI'}]},
#   {'LEI': {'$': '213800DO9NSTYUK1TB98'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '213800E3W388H4EO9B69'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '213800E441NIBHB3FD38'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '213800EZ9A2WITW38F30'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_KNOWN_PERSON'}]},
#   {'LEI': {'$': '213800F9J32XC8V52931'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_KNOWN_PERSON'}]},
#   {'LEI': {'$': '213800FBMJ9HCZRNBR75'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_KNOWN_PERSON'}]},
#   {'LEI': {'$': '213800FF8928S573BG04'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '213800FHPU6MOI2ZBW78'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '213800FK2VMYO4F6OY26'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '213800HY82SBWETMYE12'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '213800I6CY1WQ4YCXF32'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '213800I88ZI2F2HU5R28'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '213800JMXDUNQYUAFA19'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_KNOWN_PERSON'}]},
#   {'LEI': {'$': '213800KTNNAE1J5HS273'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '213800LQJLA7DDV16R75'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '213800LRX2XAX6K79D80'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_PUBLIC'}]},
#   {'LEI': {'$': '213800LX3LVPCL23ZP23'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_KNOWN_PERSON'}]},
#   {'LEI': {'$': '213800M66BXZGEQUHT22'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '213800MQUUJV98CQL716'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '213800N3QFD8AT9WRU40'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_LEI'}]},
#   {'LEI': {'$': '213800NI6NISM2CSIX84'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '213800O1ODIHCR5JBB81'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_LEI'}]},
#   {'LEI': {'$': '213800OKP4KFFPKQ4F22'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '213800ORPQK2H6XH7348'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_KNOWN_PERSON'}]},
#   {'LEI': {'$': '213800Q8Z1KI9R3KG873'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '213800QFYI8BRC7DW579'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '213800R9GXQAO5X7CS31'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '213800R9VSRA26YVE907'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_PUBLIC'}]},
#   {'LEI': {'$': '213800S1TYU42ELAFU50'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_KNOWN_PERSON'}]},
#   {'LEI': {'$': '213800S3R98XUARBN645'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '213800SHS1JDUDTHJ227'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_KNOWN_PERSON'}]},
#   {'LEI': {'$': '213800SI7HFZVMRBDL45'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '213800SJUDAA13HG8B37'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_KNOWN_PERSON'}]},
#   {'LEI': {'$': '213800SNIUTSQ7B6W189'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '213800SPYVVKXM42JX90'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '213800TX7LEAWZ6NSW98'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '213800UJH93NH8IOFQ77'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_KNOWN_PERSON'}]},
#   {'LEI': {'$': '213800UKTBOJPWUR5F91'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_LEI'}]},
#   {'LEI': {'$': '213800UN7T3Q1JIBK368'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '213800UX6RG6GVAUP776'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '213800W7NJNVLHJUOP91'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_LEI'}]},
#   {'LEI': {'$': '213800WLDLSSU5NHMG33'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '213800WSHVKZL182DG67'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '213800X9ZAN9WHDQ1X45'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_KNOWN_PERSON'}]},
#   {'LEI': {'$': '213800XBXAXOR6KJZX96'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '213800Y111RAS9Z6JZ63'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '213800Y9C7D8LRB1MV77'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_KNOWN_PERSON'}]},
#   {'LEI': {'$': '213800YESNPSQEYUQR35'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_KNOWN_PERSON'}]},
#   {'LEI': {'$': '213800YP17G9O9W2RL86'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_KNOWN_PERSON'}]},
#   {'LEI': {'$': '213800YZFW1I27C7R367'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '213800ZRY9OQESACY727'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_LEI'}]},
#   {'LEI': {'$': '2221006WLCTTCY75PM62'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '222100GWMKD5WV2AIA20'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '25490006E19J36RJSA48'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '2549000IRBDS42QBHC41'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '2549000RGU6ZEOD8B712'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '25490013B4NINQPZE538'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '25490017ITQCLF3KKS72'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '2549001DBW0RHTFEQQ68'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '2549001GFLQT206FV676'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '2549001K3131GHIF7A10'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_LEI'}]},
#   {'LEI': {'$': '2549001SOQPGAPPFD370'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_LEI'}]},
#   {'LEI': {'$': '25490026V6DWBSF4WA26'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_LEI'}]},
#   {'LEI': {'$': '25490027EAIG67C19597'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '2549002LXTWM9OU6SM93'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '2549002RV4X4NMEAOV27'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '25490037UXDRB3LTKJ26'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_LEI'}]},
#   {'LEI': {'$': '2549003AA3K5IXCAF820'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_LEI'}]},
#   {'LEI': {'$': '2549003KT36YWHIWEX86'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_LEI'}]},
#   {'LEI': {'$': '2549003SBB7SD59GG905'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '2549003WUE0SXQWU2B33'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '2549004C819TPZMQW015'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '2549004RL0G67HZ6N322'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_KNOWN_PERSON'}]},
#   {'LEI': {'$': '25490054S0KT922JQN67'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_LEI'}]},
#   {'LEI': {'$': '25490058PURNN3B3S496'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_LEI'}]},
#   {'LEI': {'$': '25490059UC4YAAKRIH50'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_KNOWN_PERSON'}]},
#   {'LEI': {'$': '2549005A89JE1O3XT371'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_LEI'}]},
#   {'LEI': {'$': '2549005GZZUID2GA9J25'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_LEI'}]},
#   {'LEI': {'$': '2549005MEHRSPXOQX385'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_KNOWN_PERSON'}]},
#   {'LEI': {'$': '2549005QB4334AT6ZW34'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '2549005SG5EUYJXCWS18'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_PUBLIC'}]},
#   {'LEI': {'$': '2549005VCT42GUN94U84'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '25490062GI1UY1BECF26'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '25490064NF9XC4EK7667'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '254900674LNVWNRXKB06'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_KNOWN_PERSON'}]},
#   {'LEI': {'$': '2549006G6FPG2SVH8A14'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '2549006O6A1OWOK5ZI75'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '254900740S0PUWS6EC63'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '2549007CIVV3OERJ7M41'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '2549007IDVGVJVXC8017'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '2549007OLM2I678IJY45'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '2549008HQDCSSVY2KQ11'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '2549009780KAF4BP4958'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '254900995OF4D17SVQ49'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '2549009BH8HIMIFFQT91'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '2549009J3B5XQ92RP548'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_LEI'}]},
#   {'LEI': {'$': '2549009QL7QZ5XBQPT96'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '254900AD11URAS0ZLQ47'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '254900AISEDU4ZYYDD21'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '254900ATFEDF4X8X9H90'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_KNOWN_PERSON'}]},
#   {'LEI': {'$': '254900AVUF1Z2PH43847'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_KNOWN_PERSON'}]},
#   {'LEI': {'$': '254900BGYIZ141B82G93'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_PUBLIC'}]},
#   {'LEI': {'$': '254900BNAYQ0TVUCPY75'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '254900BUNK6F97XOHL43'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '254900BY5LVYZUGEZY31'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '254900CD07PMUSML1U79'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '254900CED0C8TOLVFB89'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_LEI'}]},
#   {'LEI': {'$': '254900CHI3HWR423PP03'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '254900CLMAKKC3AE0E29'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_LEI'}]},
#   {'LEI': {'$': '254900CNZQE7F1ISGC54'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_LEI'}]},
#   {'LEI': {'$': '254900D3GT2FUG58S845'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '254900DBJL0WYPDXM565'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '254900DEAP6Y3FDXAJ60'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '254900DUHCR2ZPP20V38'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_PUBLIC'}]},
#   {'LEI': {'$': '254900E5TGXWUFSGQ670'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_LEI'}]},
#   {'LEI': {'$': '254900E6GRUW4S98SZ10'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '254900EFW66UGZMVVV76'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '254900EG14O2R6U3MM64'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '254900EMV12HA8MW0C12'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '254900ETYBZW63I1C270'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_LEI'}]},
#   {'LEI': {'$': '254900FCBQ5FF73ZZI33'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_LEI'}]},
#   {'LEI': {'$': '254900FJWD6QHOTC1S62'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '254900FTVW0I07Z8BU93'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_LEI'}]},
#   {'LEI': {'$': '254900FY0IP52S8F7D84'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '254900G4RMGRRWH2O772'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '254900G7FM0PQ24N9D78'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_PUBLIC'}]},
#   {'LEI': {'$': '254900GBXVMQJY7IRH74'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '254900GQ2MJ8OC9IDU64'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '254900H2TAH70UG5YF67'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_LEI'}]},
#   {'LEI': {'$': '254900H7JZ2LBZ7PK181'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '254900HDC4GV79VQZQ94'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '254900HFJRURL4CRDO42'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '254900HOD1NSS1T3UK89'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '254900HT7W21NKTKPJ22'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '254900HYUV1XIIV5BC19'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '254900I80K3UAJ5XX377'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '254900IAME8DO4QSTG40'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '254900IBCWCMNFJIAG54'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '254900ID3YSILBR1IY24'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '254900IDNR9JMON5I921'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_LEI'}]},
#   {'LEI': {'$': '254900IM80M1KQSPQV66'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '254900IY2XKKZ7E17G09'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '254900J5TQS96747AX21'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '254900JG6TZ6KBDX6390'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '254900JPLEM59L39ZI47'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '254900JT6NVUVON2G452'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '254900JT9FDXS6CNIW50'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '254900JVW3KXOAP4Y172'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '254900JYOAGYYZSRC907'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_KNOWN_PERSON'}]},
#   {'LEI': {'$': '254900K09EUHNVWN2B13'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '254900KCXDU3F0VFVR20'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '254900KKMH83IDYEJP10'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_LEI'}]},
#   {'LEI': {'$': '254900KM0P6N3Z5INK78'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '254900KNF72YVS5ORT48'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '254900KRHZ984UPNQX02'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_LEI'}]},
#   {'LEI': {'$': '254900L1JZRQMA1TU879'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_PUBLIC'}]},
#   {'LEI': {'$': '254900L9AJT3LBEI3456'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_KNOWN_PERSON'}]},
#   {'LEI': {'$': '254900LPMNF5KWBDXK91'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '254900LV3VDC59LTJH21'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '254900LXI62FUHZGH122'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_KNOWN_PERSON'}]},
#   {'LEI': {'$': '254900MEQ980BGAMWW38'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_LEI'}]},
#   {'LEI': {'$': '254900MPROYL732PM350'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '254900MUUK71LLM8LH03'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '254900NEH2WILL1UEJ38'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '254900NGJODVZDW3D903'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '254900NH0BST6JZFTL43'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_KNOWN_PERSON'}]},
#   {'LEI': {'$': '254900NR96SF0KA5I144'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}, {'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '254900O81QO43MNIYG85'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '254900O9YADZK7IZR547'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '254900OAIAQ1S55VWH44'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '254900OGBZCS4R6Z2Y97'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '254900OMN8Q4X7NZ8234'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '254900ONQFS9EQPTKM58'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_KNOWN_PERSON'}]},
#   {'LEI': {'$': '254900PE1VG1BRYEP449'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '254900PKZ7VZC1MBHU17'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '254900PMU6P5K517R017'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '254900PNTN4N90XPEW71'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '254900PPDK716J78RD92'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '254900PTSE33AKO70265'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '254900QE5ZY6FJ88GP95'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '254900QN49O1XZNXJC44'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '254900QZA4LQG2FHII50'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '254900RDZJ0ZF5YWAX41'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '254900RLMF5LWR341781'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '254900SKS2BQZ01ACS08'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '254900SY0Z11TEMY7Y04'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '254900T8310DWDGPXR37'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '254900TF36VFI7QB2210'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_PUBLIC'}]},
#   {'LEI': {'$': '254900TT30CGZ8S8P920'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '254900U5M2ZXLVI85D83'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '254900V6183B7H6GR324'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '254900WLNIV36B5ZVH54'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '254900YJ1J1RC4B2DC22'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '254900YMC51DV5BKDL40'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '3003005UII0P192V5U06'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_PUBLIC'}]},
#   {'LEI': {'$': '3157002N1ZMXFTYVOA90'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '315700H8AYJ52S9PQN11'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '3358001RP33D3B26XG90'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '3358003KATZ6UESTDR90'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_KNOWN_PERSON'}]},
#   {'LEI': {'$': '33580075KUSQSDEPB565'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_KNOWN_PERSON'}]},
#   {'LEI': {'$': '3358007KWDHTFCREGZ16'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '335800CH71BAQ113ZK02'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '335800DB4OPDU5GX2939'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '335800HQBHVGHDT4C660'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '335800NDSLK26OKF6D60'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '335800O1ZHJN6LTGB278'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '335800U1DHVPIRN31Z92'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '335800UEPPXNXVQ6LE53'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '335800XBGEZANE2XR708'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '335800ZYADNHHSWBGF56'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '39120000UR2FWQRHTH15'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_KNOWN_PERSON'}]},
#   {'LEI': {'$': '39120010G0OOOEYB6570'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_KNOWN_PERSON'}]},
#   {'LEI': {'$': '3912001IPPGYLBXXEP56'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '3912002MLWGOPTQUNB92'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_KNOWN_PERSON'}]},
#   {'LEI': {'$': '3912002Z9C02Q42LX692'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_KNOWN_PERSON'}]},
#   {'LEI': {'$': '3912003P72XXPKHPZA11'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_KNOWN_PERSON'}]},
#   {'LEI': {'$': '3912004OZNSLHV2LKP57'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_KNOWN_PERSON'}]},
#   {'LEI': {'$': '3912005381M5WDLAHM91'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_KNOWN_PERSON'}]},
#   {'LEI': {'$': '3912007KOV23CS00HW75'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '391200842DBZQ0BGAK55'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_KNOWN_PERSON'}]},
#   {'LEI': {'$': '391200CHL19IS028AZ53'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_KNOWN_PERSON'}]},
#   {'LEI': {'$': '391200DF5WVX7KHN0Q29'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_KNOWN_PERSON'}]},
#   {'LEI': {'$': '391200KVCI3DM8ZTEY54'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_KNOWN_PERSON'}]},
#   {'LEI': {'$': '391200MTZII8R5QON953'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_KNOWN_PERSON'}]},
#   {'LEI': {'$': '391200N25O0YSP205X36'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_KNOWN_PERSON'}]},
#   {'LEI': {'$': '391200NPW2PGRV5AKR89'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_KNOWN_PERSON'}]},
#   {'LEI': {'$': '391200PE3QKBEOCQSE40'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_KNOWN_PERSON'}]},
#   {'LEI': {'$': '391200S3WRFK2CGRSY13'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '391200SFQSXX351OZB86'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_KNOWN_PERSON'}]},
#   {'LEI': {'$': '391200VJKDNIC3JT5S73'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_KNOWN_PERSON'}]},
#   {'LEI': {'$': '391200Y2SJLE8Q0RHG55'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '391200YZBA1084WUDJ60'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_KNOWN_PERSON'}]},
#   {'LEI': {'$': '4851003HFYW8PHNDQS27'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '485100R8QU6W2OIA8418'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '485100VKV3C2O0AQI079'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '5299000FK7SUSCPHLD93'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '5299008F25F6XKHKUO56'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '52990095E5YF4ZOHFY48'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '529900GEFKTYUB2XXL31'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '54930008IVIXHBWZWA84'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_KNOWN_PERSON'}]},
#   {'LEI': {'$': '5493000DPQH6PHSUAM13'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '5493000YQS5ERLZUXJ50'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_PUBLIC'}]},
#   {'LEI': {'$': '549300185WV57X3U8N23'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '5493002FYFEVLD4JBD64'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '5493002MYNPY7M47FM26'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_PUBLIC'}]},
#   {'LEI': {'$': '5493002VIAERYU414F79'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_KNOWN_PERSON'}]},
#   {'LEI': {'$': '5493004K7OQGNX0KGT40'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '549300504U6FLN5QQE66'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_PUBLIC'}]},
#   {'LEI': {'$': '5493005UPG0G60H57G86'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '5493006U0IKGNNTPJN11'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_KNOWN_PERSON'}]},
#   {'LEI': {'$': '54930070AI87YJYPIR94'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '54930073ISTVRMJU1L04'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '5493007MJ3BLX55XSZ63'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '5493007XK0YVDXPBXL90'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '549300BIT7ZNW233C316'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '549300BZDBLPR5LUOJ48'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '549300CTC0WHN3Z4D744'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '549300DI8GT3CGLXR761'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '549300DW3X9LUM8LE763'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_PUBLIC'}]},
#   {'LEI': {'$': '549300EUGHED4XCALO98'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '549300FW7FXV31C58832'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '549300GXZOTKBXWC3K15'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '549300HPXKX567WQKL82'},
#    'ExceptionCategory': {'$': 'DIRECT_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_KNOWN_PERSON'}]},
#   {'LEI': {'$': '549300I474BZ65QPSI93'},
# ...
#    'ExceptionReason': [{'$': 'NO_KNOWN_PERSON'}]},
#   {'LEI': {'$': '391200MTZII8R5QON953'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_KNOWN_PERSON'}]},
#   {'LEI': {'$': '391200N25O0YSP205X36'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_KNOWN_PERSON'}]},
#   {'LEI': {'$': '391200NPW2PGRV5AKR89'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_KNOWN_PERSON'}]},
#   {'LEI': {'$': '391200PE3QKBEOCQSE40'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_KNOWN_PERSON'}]},
#   {'LEI': {'$': '391200S3WRFK2CGRSY13'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '391200SFQSXX351OZB86'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_KNOWN_PERSON'}]},
#   {'LEI': {'$': '391200VJKDNIC3JT5S73'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_KNOWN_PERSON'}]},
#   {'LEI': {'$': '391200Y2SJLE8Q0RHG55'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '391200YZBA1084WUDJ60'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_KNOWN_PERSON'}]},
#   {'LEI': {'$': '4851003HFYW8PHNDQS27'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '485100R8QU6W2OIA8418'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '485100VKV3C2O0AQI079'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '5299000FK7SUSCPHLD93'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '5299008F25F6XKHKUO56'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '52990095E5YF4ZOHFY48'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '529900GEFKTYUB2XXL31'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '54930008IVIXHBWZWA84'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_KNOWN_PERSON'}]},
#   {'LEI': {'$': '5493000DPQH6PHSUAM13'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '5493000YQS5ERLZUXJ50'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_PUBLIC'}]},
#   {'LEI': {'$': '549300185WV57X3U8N23'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '5493001FRGSQDYPZ3H57'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_KNOWN_PERSON'}]},
#   {'LEI': {'$': '5493002FYFEVLD4JBD64'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '5493002MYNPY7M47FM26'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_PUBLIC'}]},
#   {'LEI': {'$': '5493002VIAERYU414F79'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_KNOWN_PERSON'}]},
#   {'LEI': {'$': '5493004K7OQGNX0KGT40'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '549300504U6FLN5QQE66'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_PUBLIC'}]},
#   {'LEI': {'$': '5493005UPG0G60H57G86'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '5493006U0IKGNNTPJN11'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_KNOWN_PERSON'}]},
#   {'LEI': {'$': '54930070AI87YJYPIR94'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '54930073ISTVRMJU1L04'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '5493007MJ3BLX55XSZ63'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '5493007XK0YVDXPBXL90'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '549300BIT7ZNW233C316'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '549300BZDBLPR5LUOJ48'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '549300CTC0WHN3Z4D744'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '549300DI8GT3CGLXR761'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '549300DW3X9LUM8LE763'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_PUBLIC'}]},
#   {'LEI': {'$': '549300EUGHED4XCALO98'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '549300FW7FXV31C58832'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '549300GXZOTKBXWC3K15'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '549300HPXKX567WQKL82'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_KNOWN_PERSON'}]},
#   {'LEI': {'$': '549300I474BZ65QPSI93'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '549300IDDGNKQFGMQG77'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '549300J5TCJMK882VM58'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '549300KRO6MQJXPFUK41'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '549300KX38K2K74WY822'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '549300L4D1WXY3OLT352'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_KNOWN_PERSON'}]},
#   {'LEI': {'$': '549300LOX6H3YEE3PE37'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '549300N6X1E83OKJR698'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '549300N8YPT3YUMYQ744'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '549300OM93697RR7ST39'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '549300P4OAC5PKDIP053'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '549300PPA7FU34WFGK59'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_KNOWN_PERSON'}]},
#   {'LEI': {'$': '549300PRKH7JK9QG6U18'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '549300QKBPLQWUGVVS04'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '549300S5WHVS0EY7TU16'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '549300SBQUF7FIXZI265'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '549300SRIXMP382B3J12'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '549300V85WE85XQ1O653'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '549300VFW4QE3O2RHX55'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '549300W1HU4P5L8CLI77'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '549300WDQFL9DFNLC197'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '549300Y0VOU3K3QIYE96'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '549300Y7KAK18QL3ET91'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '549300YB58FQSC1HDZ34'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '549300YHWP3H2TIVZ195'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_PUBLIC'}]},
#   {'LEI': {'$': '549300Z45X2X1WG4Y724'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '549300ZC9U6ZILO4G947'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '549300ZIPXEDV0445R18'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '5MPOLR0VX51RN7HQ1I97'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_KNOWN_PERSON'}]},
#   {'LEI': {'$': '6354009CSVUBJPCIZW94'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '635400BQAJCNI1YDVQ92'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '635400RWUJCVPPT1T158'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '636700262EQMWIHOJO97'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '636700BPYIZ6MJDOU026'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '636700Q8OV64XNZOBQ75'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '636700Y6D56GQSOY9Q72'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '64880ITOCX2QC7992187'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NO_KNOWN_PERSON'}]},
#   {'LEI': {'$': '648821MC97O755RYVA45'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '648824VO8LFF78K17S84'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '64883CTUV9Y38RG07408'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '648884LK35JE13UCK233'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '648898JK2W63N2B4JE18'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '64889C4451LWY69ZRL37'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '64889R36L96WA8L2HC49'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '64889U3ZAWL0W01S6204'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '6488B00WFAZ17GT30684'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '6488BL0QR673G853RJ68'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '6488E4Y7IWF76M56W024'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '6488H9195ANY26BWH352'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '6488I9Y8O4PJ5KY71006'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '6488L858EVR0Z24Z9X85'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '6488M4P360XE0R6Y5L10'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   {'LEI': {'$': '6488P16E30B4KA8T8C49'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NATURAL_PERSONS'}]},
#   {'LEI': {'$': '6488PIB13T3V1D771T06'},
#    'ExceptionCategory': {'$': 'ULTIMATE_ACCOUNTING_CONSOLIDATION_PARENT'},
#    'ExceptionReason': [{'$': 'NON_CONSOLIDATING'}]},
#   ...]}
